# %%
pip install nbformat ipython
# Out:
# Collecting nbformat
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: ipython in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (9.5.0)
# Collecting fastjsonschema>=2.15 (from nbformat)
#   Downloading fastjsonschema-2.21.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from nbformat) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from nbformat) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: colorama in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from ipython) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from ipython) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from ipython) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from jedi>=0.16->ipython) (0.8.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from jsonschema>=2.6->nbformat) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.4.0)
# Requirement already satisfied: pywin32>=300 in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (311)
# Requirement already satisfied: executing>=1.2.0 in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from stack_data->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from stack_data->ipython) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\viriya gunawan lim\projects\helloworld\.venv\lib\site-packages (from stack_data->ipython) (0.2.3)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Downloading fastjsonschema-2.21.2-py3-none-any.whl (24 kB)
# Installing collected packages: fastjsonschema, nbformat
#
#    ---------------------------------------- 0/2 [fastjsonschema]
#    -------------------- ------------------- 1/2 [nbformat]
#    -------------------- ------------------- 1/2 [nbformat]
#    -------------------- ------------------- 1/2 [nbformat]
#    -------------------- ------------------- 1/2 [nbformat]
#    ---------------------------------------- 2/2 [nbformat]
#
# Successfully installed fastjsonschema-2.21.2 nbformat-5.10.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: You must give at least one requirement to install (see "pip help install")

# %%
import plotly.graph_objects as go 
import plotly.express as px
import pandas as pd 
import numpy as np

# %%
print("Hello World")
# Out:
# Hello World

# %%
# Sample data 
x = [1, 2, 3, 4, 5] 
y = [10, 6, 8, 12, 4]  
# Create a bar chart 

fig = go.Figure(data=go.Bar(x=x, y=y)) 
fig.show()
